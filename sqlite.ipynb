# %%
# %%!
# pip install --trusted-host pypi.org ipython-sql #sql veritabanına bağlanmak için indirilmesi gereken kütüphanenin indirilmesi
# Out:
# ["ERROR: Invalid requirement: '#sql'"]

# %%
# %load_ext sql #sql aktifleme
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-7b4d45e27b45> in <module>
# ----> 1 get_ipython().run_line_magic('load_ext', 'sql #sql aktifleme')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ...

# %%
# %sql sqlite:///vbo.db #veri tabanına bağlandı

# %%
# %%sql
# SELECT * FROM Customers LIMIT 3;

# %% [markdown]
# ## Manuel Tablo Oluşturma İşlemleri

# %%
# %%sql
# CREATE TABLE yeni_tablo(firstname varchar(20),
#                        lastname varchar(20));
#
# #Varchar değişkenin tipini tanımlamada işe yarar
# Out:
#  * sqlite:///vbo.db
# (sqlite3.OperationalError) database is locked
# [SQL: CREATE TABLE yeni_tablo(firstname varchar(20),
#                        lastname varchar(20));]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
# %%sql
# INSERT INTO yeni_tablo values("Ali","Uzaya_git");
# Out:
#  * sqlite:///vbo.db
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-15-b1741f86780e> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', 'INSERT INTO yeni_tablo values("Ali","Uzaya_git");\n')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
# ...

# %%
# %%sql
# SELECT * FROM yeni_tablo;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('mehmet', 'soyadı'), ('Ali', 'Uzaya_git')]

# %%
# %%sql
# INSERT INTO yeni_tablo values("Işık","Süte_devam");
# Out:
#  * sqlite:///vbo.db
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-18-7199e67e946f> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', 'INSERT INTO yeni_tablo values("Işık","Süte_devam");\n')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# C:\ProgramData\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
# ...

# %%
# %%sql
# SELECT * FROM yeni_tablo;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('mehmet', 'soyadı'), ('Ali', 'Uzaya_git'), ('Işık', 'Süte_devam')]

# %% [markdown]
# ## SELECT İŞLEMLERİ

# %%
# %%sql
# SELECT * FROM Products LIMIT 5;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21)]

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type = "table"; #veritabanındaki tabloların ismini çekmeye yarar
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Products',),
#  ('Categories',),
#  ('Customers',),
#  ('Employees',),
#  ('OrderDetails',),
#  ('Orders',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('yeni_tablo',)]

# %%
# %%sql
# SELECT * FROM Customers WHERE 1 = 0; #sadece değişken isimlerine erişmek
# Out:
#  * sqlite:///vbo.db
# Done.
# []

# %%
# %%sql
# SELECT CustomerName,City,Country From Customers LIMIT 5 ;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Alfreds Futterkiste', 'Berlin', 'Germany'),
#  ('Ana Trujillo Emparedados y helados', 'México D.F.', 'Mexico'),
#  ('Antonio Moreno Taquería', 'México D.F.', 'Mexico'),
#  ('Around the Horn', 'London', 'UK'),
#  ('Berglunds snabbköp', 'Luleå', 'Sweden')]

# %%
# %%sql
# SELECT * FROM Products LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10)]

# %%
# %%sql
# SELECT price, price*2 FROM Products LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(18, 36), (19, 38), (10, 20)]

# %%
#alias : takma isim,kısayol

# %%
# %%sql
# SELECT price as ilk_price, price*2 as islemli_price FROM Products LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(18, 36), (19, 38), (10, 20)]

# %%
#count : saydırma işlemi yapar

# %%
# %%sql
# select count(*) as saydirma_sayisi from customers;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(91,)]

# %%
#order by : sıralama işlemi yapmak için kullanılır

# %%
# %%sql
# SELECT * FROM Products LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10)]

# %%
# %%sql
# SELECT * FROM Products order by price desc LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(31, 'Gorgonzola Telino', 14, 4, '12 - 100 g pkgs', 435),
#  (38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263),
#  (29, 'Thüringer Rostbratwurst', 12, 6, '50 bags x 30 sausgs.', 123),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81),
#  (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62),
#  (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55),
#  (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53),
#  (62, 'Tarte au sucre', 29, 3, '48 pies', 49),
#  (43, 'Ipoh Coffee', 20, 1, '16 - 500 g tins', 46)]

# %% [markdown]
# ### WHERE

# %%
# %%sql
# select * from customers limit 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
# ...

# %%
#text string seçimb 
# %%sql
select * from customers where country = "Sweden"
# Out:
#  * sqlite:///vbo.db
# Done.
# [(5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (24, 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')]

# %%
# %%sql
# select * from customers where city = "Berlin"
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')]

# %%
# %%sql
# select * from customers where not city = "Berlin"
# Out:
#  * sqlite:///vbo.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
# ...

# %%
#numerik seçimler

# %%
# %%sql
# select * from customers where postalcode = 5021;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico')]

# %%
# %%sql
# select * from customers where postalcode > 5021;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK'),
# ...

# %%
#and ve or ifadeleri

# %%
# %%sql
# select * from customers limit 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
# ...

# %%
# %%sql
# select * from customers where city = "Berlin" or country ="Mexico";
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (58, 'Pericles Comidas clásicas', 'Guillermo Fernández', 'Calle Dr. Jorge Cash 321', 'México D.F.', '5033', 'Mexico'),
#  (80, 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123', 'México D.F.', '5033', 'Mexico')]

# %%
# %%sql
# select * from customers where country = "USA" ;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
#  (48, 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA'),
#  (55, 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA'),
#  (65, 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA'),
#  (71, 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA'),
#  (75, 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA'),
# ...

# %%
# %%sql
# select * from customers where country = 'USA' and (city ='Eugene' or city = 'Elgin');
# Out:
#  * sqlite:///vbo.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')]

# %%
# %%sql
# select * from customers where country = 'USA' and (city ='Eugene' or city = 'Elgin') and Postalcode = 97403;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')]

# %%
#in/not in kullanımı

# %%
# %%sql
# select * from customers where customerid in (1,3,5,7) ;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France')]

# %%
# %%sql
# select * from customers where country = 'USA' and city in ('Elgin','Eugene') ;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')]

# %%
# %%sql
# select * from customers where country = 'USA' and city not in ('Elgin','Eugene') ;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
#  (48, 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA'),
#  (55, 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA'),
#  (65, 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA'),
#  (71, 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA'),
#  (75, 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA'),
#  (77, 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA'),
#  (78, 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA'),
# ...

# %% [markdown]
# ### LIKE ile Seçim İşlemleri
# + 'a%' : "a" ile başlayan değerler
# + '%a' : "a" ile biten değerler
# + '%or%': herhangi bir yerinde "or" olan değerler
# + '_r%' : ikinci sırasında "r" olan değerler
# + 'a%%' : "a" ile başlayıp en az 3 karakterden oluşan değerler
# +'a%o' : "a" ile başlayıp "o" ile biten değerler

# %%
# %%sql
# select * from customers limit 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
# ...

# %%
# %%sql
# select * from customers where customername like '%or%' limit 10 ;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (40, "La corne d'abondance", 'Daniel Tonini', "67, avenue de l'Europe", 'Versailles', '78000', 'France'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (52, 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '4179', 'Germany'),
#  (53, 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK'),
#  (55, 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA'),
#  (72, 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK'),
# ...

# %%
# %%sql
# select * from customers where customername like '%a' limit 10 ;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (30, 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero, 33', 'Sevilla', '41101', 'Spain'),
#  (61, 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora, 12', 'Rio de Janeiro', '02389-673', 'Brazil'),
#  (62, 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios, 891', 'São Paulo', '05487-020', 'Brazil'),
#  (88, 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado, 12', 'Resende', '08737-363', 'Brazil'),
#  (90, 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')]

# %%
# %%sql
# select * from customers where customername like 'a%' and country like '%il' limit 10 ;
# Out:
#  * sqlite:///vbo.db
# Done.
# []

# %% [markdown]
# ### BETWEEN

# %%
# %%sql
# select * from PRODUCTS limit 10 ;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31)]

# %%
# %%sql
# select * from PRODUCTS where price between 10 and 20  limit 10 ;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (16, 'Pavlova', 7, 3, '32 - 500 g boxes', 17),
#  (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10),
#  (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14),
#  (34, 'Sasquatch Ale', 16, 1, '24 - 12 oz bottles', 14),
#  (35, 'Steeleye Stout', 16, 1, '24 - 12 oz bottles', 18),
#  (36, 'Inlagd Sill', 17, 8, '24 - 250 g jars', 19),
#  (39, 'Chartreuse verte', 18, 1, '750 cc per bottle', 18)]

# %%
# %%sql
# select * from PRODUCTS where price not between 10 and 20  limit 10 ;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31),
#  (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21),
#  (12, 'Queso Manchego La Pastora', 5, 4, '10 - 500 g pkgs.', 38),
#  (13, 'Konbu', 6, 8, '2 kg box', 6)]

# %%
# %%sql
# select * from PRODUCTS where (price between 10 and 20 )and categoryid not in(1,2,3) ;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(36, 'Inlagd Sill', 17, 8, '24 - 250 g jars', 19),
#  (42, 'Singaporean Hokkien Fried Mee', 20, 5, '32 - 1 kg pkgs.', 14),
#  (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12),
#  (54, 'Tourtière', 25, 6, '16 pies', 16),
#  (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13),
#  (73, 'Röd Kaviar', 17, 8, '24 - 150 g jars', 15),
#  (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10)]

# %%
# %%sql
# select productname from PRODUCTS where (price between 10 and 20 )and categoryid not in(1,2,3) ;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Inlagd Sill',),
#  ('Singaporean Hokkien Fried Mee',),
#  ('Spegesild',),
#  ('Tourtière',),
#  ('Escargots de Bourgogne',),
#  ('Röd Kaviar',),
#  ('Longlife Tofu',)]

# %%
# %%sql
# select * from PRODUCTS where productname between 'Carnarvon Tigers' and 'Mozzarella di Govanni' limit 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31),
#  (13, 'Konbu', 6, 8, '2 kg box', 6),
#  (15, 'Genen Shouyu', 6, 2, '24 - 250 ml bottles', 43),
#  (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62)]

# %% [markdown]
# ### Aggregation Fonksiyonları: Temel İstatistiksel İşlemler

# %%
# %%sql
# select * from products limit 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31)]

# %%
# %%sql
# select min(price) from products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(6,)]

# %% [markdown]
# # min ve max

# %%
# %%sql
# select min(price),max(price) from products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(6, 435)]

# %% [markdown]
# # ortalama

# %%
# %%sql
# select min(price),max(price),avg(price) from products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(6, 435, 39.15584415584416)]

# %% [markdown]
# # toplama

# %%
# %%sql
# select min(price),max(price),sum(price) from products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(6, 435, 3015)]

# %%
# %%sql
# select count(*), min(price),max(price),avg(price),sum(price) from products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(77, 6, 435, 39.15584415584416, 3015)]

# %% [markdown]
# # GroupBy ve Aggregation Fonksiyonları

# %%
# %%sql
# select * from customers limit 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
# %%sql
# select count(*) as musteri,country  from customers group by country order by musteri desc;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(13, 'USA'),
#  (11, 'Germany'),
#  (11, 'France'),
#  (9, 'Brazil'),
#  (7, 'UK'),
#  (5, 'Spain'),
#  (5, 'Mexico'),
#  (4, 'Venezuela'),
#  (3, 'Italy'),
#  (3, 'Canada'),
#  (3, 'Argentina'),
#  (2, 'Switzerland'),
#  (2, 'Sweden'),
#  (2, 'Portugal'),
#  (2, 'Finland'),
#  (2, 'Denmark'),
#  (2, 'Belgium'),
#  (2, 'Austria'),
#  (1, 'Poland'),
#  (1, 'Norway'),
#  (1, 'Ireland')]

# %%
# %%sql
# select * from products limit 2;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19)]

# %%
# %%sql
# select avg(price),CategoryID from products group by CategoryID order by avg(price) desc;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(74.9, 4),
#  (55.166666666666664, 6),
#  (42.75, 1),
#  (33.76923076923077, 3),
#  (32.2, 7),
#  (28.25, 2),
#  (26.5, 8),
#  (23.571428571428573, 5)]

# %% [markdown]
# # JOIN İŞLEMLERİ

# %%
# %%sql
#
# select * from categories limit 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (3, 'Confections', 'Desserts, candies, and sweet breads')]

# %%
# %%sql
# select * from products limit 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10)]

# %% [markdown]
# # left join BİRLEŞTİRME İŞLEMİ

# %%
# %%sql
# select * from products LEFT  OUTER JOIN Categories on products.categoryid = categories.categoryid limit 5;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings')]

# %%
# %%sql
# select pr.productname, ca.categoryid,ca.categoryname from products  pr LEFT  OUTER JOIN Categories  ca on pr.categoryid = ca.categoryid limit 5;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Chais', 1, 'Beverages'),
#  ('Chang', 1, 'Beverages'),
#  ('Aniseed Syrup', 2, 'Condiments'),
#  ("Chef Anton's Cajun Seasoning", 2, 'Condiments'),
#  ("Chef Anton's Gumbo Mix", 2, 'Condiments')]

# %% [markdown]
# ### inner join

# %%
# %%sql
# select * from customers limit 4;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')]

# %%
# %%sql
# select * from orders limit 4;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(10248, 90, 5, '4.07.1996', 3),
#  (10249, 81, 6, '5.07.1996', 1),
#  (10250, 34, 4, '8.07.1996', 2),
#  (10251, 84, 3, '8.07.1996', 1)]

# %%
# %%sql
# select orders.orderid,customers.customername from orders inner join customers on orders.customerid = customers.customerid;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(10248, 'Wilman Kala'),
#  (10249, 'Tradição Hipermercados'),
#  (10250, 'Hanari Carnes'),
#  (10251, 'Victuailles en stock'),
#  (10252, 'Suprêmes délices'),
#  (10253, 'Hanari Carnes'),
#  (10254, 'Chop-suey Chinese'),
#  (10255, 'Richter Supermarkt'),
#  (10256, 'Wellington Importadora'),
#  (10257, 'HILARIÓN-Abastos'),
#  (10258, 'Ernst Handel'),
#  (10259, 'Centro comercial Moctezuma'),
#  (10260, 'Old World Delicatessen'),
#  (10261, 'Que Delícia'),
#  (10262, 'Rattlesnake Canyon Grocery'),
#  (10263, 'Ernst Handel'),
#  (10264, 'Folk och fä HB'),
#  (10265, 'Blondel père et fils'),
#  (10266, 'Wartian Herkku'),
#  (10267, 'Frankenversand'),
#  (10268, 'GROSELLA-Restaurante'),
#  (10269, 'White Clover Markets'),
#  (10270, 'Wartian Herkku'),
#  (10271, 'Split Rail Beer & Ale'),
#  (10272, 'Rattlesnake Canyon Grocery'),
#  (10273, 'QUICK-Stop'),
#  (10274, 'Vins et alcools Chevalier'),
#  (10275, 'Magazzini Alimentari Riuniti'),
# ...

# %%
# %%sql
# select count(*) from (select orders.orderid,customers.customername from orders inner join customers on orders.customerid = customers.customerid);
# Out:
#  * sqlite:///vbo.db
# Done.
# [(196,)]

# %% [markdown]
# # SQL ve Pandas DataFrame Operasyonları

# %%
import pandas as pd

# %%
df = %sql select count(*) as musteri,country  from customers group by country order by musteri desc;
# Out:
#  * sqlite:///vbo.db
# Done.

# %%
df
# Out:
# [(13, 'USA'),
#  (11, 'Germany'),
#  (11, 'France'),
#  (9, 'Brazil'),
#  (7, 'UK'),
#  (5, 'Spain'),
#  (5, 'Mexico'),
#  (4, 'Venezuela'),
#  (3, 'Italy'),
#  (3, 'Canada'),
#  (3, 'Argentina'),
#  (2, 'Switzerland'),
#  (2, 'Sweden'),
#  (2, 'Portugal'),
#  (2, 'Finland'),
#  (2, 'Denmark'),
#  (2, 'Belgium'),
#  (2, 'Austria'),
#  (1, 'Poland'),
#  (1, 'Norway'),
#  (1, 'Ireland')]

# %%
type(df)
# Out:
# sql.run.ResultSet

# %%
dff = pd.DataFrame(df, columns = ["mus_say","ulke"])

# %%
dff.head()
# Out:
#    mus_say     ulke
# 0       13      USA
# 1       11  Germany
# 2       11   France
# 3        9   Brazil
# 4        7       UK

# %%
dff.plot.barh(x = "ulke",y = "mus_say")
# Out:
# <AxesSubplot:ylabel='ulke'>

# %% [markdown]
# # sqlite3

# %%
import sqlite3

# %%
conn = sqlite3.connect('vbo.db')

# %%
c = conn.cursor() # cursor, sorguları çalıştırmak için kullanılır

# %%
# ?pd.read_sql
# Out:
# Signature:
# pd.read_sql(
#     sql,
#     con,
#     index_col=None,
#     coerce_float=True,
#     params=None,
#     parse_dates=None,
#     columns=None,
#     chunksize: Union[int, NoneType] = None,
# ) -> Union[pandas.core.frame.DataFrame, Iterator[pandas.core.frame.DataFrame]]
# Docstring:
# Read SQL query or database table into a DataFrame.
#
# This function is a convenience wrapper around ``read_sql_table`` and
# ``read_sql_query`` (for backward compatibility). It will delegate
# to the specific function depending on the provided input. A SQL query
# will be routed to ``read_sql_query``, while a database table name will
# be routed to ``read_sql_table``. Note that the delegated function might
# have more specific notes about their functionality not listed here.
#
# Parameters
# ----------
# sql : str or SQLAlchemy Selectable (select or text object)
#     SQL query to be executed or a table name.
# con : SQLAlchemy connectable, str, or sqlite3 connection
# ...

# %%
# read_sql

# %%
pd.read_sql("""SELECT 
COUNT(Customerid) as musteri_sayisi, 
country from customers 
group by country;""",conn)
# Out:
#     musteri_sayisi      Country
# 0                3    Argentina
# 1                2      Austria
# 2                2      Belgium
# 3                9       Brazil
# 4                3       Canada
# 5                2      Denmark
# 6                2      Finland
# 7               11       France
# 8               11      Germany
# 9                1      Ireland
# 10               3        Italy
# 11               5       Mexico
# 12               1       Norway
# 13               1       Poland
# 14               2     Portugal
# 15               5        Spain
# 16               2       Sweden
# 17               2  Switzerland
# 18               7           UK
# 19              13          USA
# 20               4    Venezuela

# %%
ab = pd.read_sql("""SELECT 
COUNT(Customerid) as musteri_sayisi, 
country from customers 
group by country;""",conn)

# %%
ab
# Out:
#     musteri_sayisi      Country
# 0                3    Argentina
# 1                2      Austria
# 2                2      Belgium
# 3                9       Brazil
# 4                3       Canada
# 5                2      Denmark
# 6                2      Finland
# 7               11       France
# 8               11      Germany
# 9                1      Ireland
# 10               3        Italy
# 11               5       Mexico
# 12               1       Norway
# 13               1       Poland
# 14               2     Portugal
# 15               5        Spain
# 16               2       Sweden
# 17               2  Switzerland
# 18               7           UK
# 19              13          USA
# 20               4    Venezuela

# %%
#conn.close()

# %%
c.execute("select customername from customers limit 5;")

# %%
c.fetchone()
# Out:
# ('Alfreds Futterkiste',)

# %%
c.fetchall()
# Out:
# [('Ana Trujillo Emparedados y helados',),
#  ('Antonio Moreno Taquería',),
#  ('Around the Horn',),
#  ('Berglunds snabbköp',)]

# %%
for row in c.execute("select customername from customers limit 5;"):
    print(row)
# Out:
# ('Alfreds Futterkiste',)
# ('Ana Trujillo Emparedados y helados',)
# ('Antonio Moreno Taquería',)
# ('Around the Horn',)
# ('Berglunds snabbköp',)
